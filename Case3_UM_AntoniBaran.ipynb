# %% [markdown]
# <a href="https://colab.research.google.com/github/Antekba/Uczenie-maszynowe/blob/main/Case3_UM_AntoniBaran.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd


data = yf.download('AMZN', start='2024-01-01', end='2024-06-05')


data.to_csv('AMZN_stock_data.csv')

print(data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  151.539993  152.380005  148.389999  149.929993  149.929993
# 2024-01-03  149.199997  151.050003  148.330002  148.470001  148.470001
# 2024-01-04  145.589996  147.380005  144.050003  144.570007  144.570007
# 2024-01-05  144.690002  146.589996  144.529999  145.240005  145.240005
# 2024-01-08  146.740005  149.399994  146.149994  149.100006  149.100006
#
#               Volume
# Date
# 2024-01-02  47339400
# 2024-01-03  49425500
# 2024-01-04  56039800
# 2024-01-05  45124800
# 2024-01-08  46757100

# %%
# !pip install backtesting
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for backtesting: filename=Backtesting-0.3.3-py3-none-any.whl size=173916 sha256=89a1776eb22987e8cf1c0ba3e8da7d694c404dd06f77183ecdf6882ca0e34a90
#   Stored in directory: /root/.cache/pip/wheels/e2/30/7f/19cbe31987c6ebdb47f1f510343249066711609e3da2d57176
# Successfully built backtesting
# ...

# %%
from backtesting import Backtest, Strategy
from backtesting.lib import crossover
import pandas as pd

def SMA(values, n):
    """Prosta średnia krocząca"""
    return pd.Series(values).rolling(n).mean()

class SmaCross(Strategy):
    n1 = 20
    n2 = 30

    def init(self):
        self.sma1 = self.I(SMA, self.data.Close, self.n1)
        self.sma2 = self.I(SMA, self.data.Close, self.n2)

    def next(self):
        if crossover(self.sma1, self.sma2):
            self.buy()
        elif crossover(self.sma2, self.sma1):
            self.sell()


data = pd.read_csv('AMZN_stock_data.csv', index_col='Date', parse_dates=True)


bt = Backtest(data, SmaCross, cash=10000, commission=.002)


output = bt.run()
print(output)
bt.plot()
# Out:
# Start                     2024-01-02 00:00:00
# End                       2024-06-04 00:00:00
# Duration                    154 days 00:00:00
# Exposure Time [%]                   17.757009
# Equity Final [$]                 10490.211514
# Equity Peak [$]                  10551.411359
# Return [%]                           4.902115
# Buy & Hold Return [%]               19.615824
# Return (Ann.) [%]                   11.930852
# Volatility (Ann.) [%]                5.772993
# Sharpe Ratio                         2.066667
# Sortino Ratio                        4.812876
# Calmar Ratio                         9.245246
# Max. Drawdown [%]                   -1.290485
# Avg. Drawdown [%]                   -0.744237
# Max. Drawdown Duration        6 days 00:00:00
# Avg. Drawdown Duration        5 days 00:00:00
# # Trades                                    2
# Win Rate [%]                            100.0
# Best Trade [%]                       5.038418
# ...
